# %% [markdown]
# # Hospital Readmission Risk — Complete ML Pipeline
#
# **Single notebook** covering the full machine-learning lifecycle for 30-day hospital readmission prediction.
#
# | Requirement | Value |
# |-------------|--------|
# | Dataset source | [UCI Diabetes 130-US Hospitals (1999–2008)](https://archive.ics.uci.edu/dataset/296/diabetes+130-us+hospitals+for+years+1999-2008) |
# | Minimum rows | **200,000** |
# | Target variable | `readmitted` (1 = readmitted within 30 days) |
# | Models | Logistic Regression, Decision Tree, Random Forest, XGBoost, Neural Network |
#
# **Run all cells top-to-bottom.** Set `USER_EMAIL` in `ml_utils.py` before deployment cells.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 1. Problem Definition
#
#
#     **Clinical problem:** Predict whether a diabetic patient will be **readmitted within 30 days** after hospital discharge.
#
#     **Business objective:** Enable care teams to prioritise high-risk patients for follow-up and reduce avoidable readmissions.
#
#     **ML task:** Binary classification on structured EHR/tabular encounter data.
#
#     **Success metrics:** Accuracy, precision, recall, F1-score, ROC-AUC, PR-AUC; clinical utility via risk stratification (low / moderate / high).

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 2. Data Acquisition
#
# Download the UCI Diabetes 130-US Hospitals dataset, clean encounters, engineer features, and expand to **≥200,000 rows** (bootstrap + numeric perturbation from ~102k real records).

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 3. Data Understanding
#
# Profile schema, dtypes, missing values, and basic target prevalence on the full acquired dataset.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 4. Data Cleaning & Preprocessing
#
#
#     - Impute missing numeric values (mean) and categoricals (`Unknown`)
#     - Label-encode categorical features
#     - Standard-scale numeric features
#     - IQR outlier detection (report only)
#     - Register dataset in the application database

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 5. Exploratory Data Analysis (EDA)
#
# Visualise missing values, class balance, correlations, readmission rates by category, and numeric summaries (10k sample for chart performance).

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 6. Feature Engineering
#
#
#     Engineered during acquisition (see `scripts/prepare_diabetes_dataset.py`):
#
#     - `admission_source`, `medical_specialty`, `payer_code` (grouped top categories)
#     - `primary_diagnosis_group`, `secondary_diagnosis_group` (ICD grouping)
#     - `total_prior_visits` = outpatient + emergency + inpatient visits
#     - `lab_procedures`, `diagnosis_count` from UCI clinical counts

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 7. Feature Selection
#
# Remove highly correlated features (>0.95) and rank remaining features with ANOVA F-score (`SelectKBest`).

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 8. Data Splitting
#
# 80/20 stratified train/test split. SMOTE applied on training set when dataset < 250k rows.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 9. Model Selection
#
#
#     | Model | Rationale |
#     |-------|-----------|
#     | Logistic Regression | Interpretable linear baseline |
#     | Decision Tree | Simple non-linear rules |
#     | Random Forest | Robust ensemble for tabular healthcare data |
#     | XGBoost | State-of-the-art gradient boosting |
#     | Neural Network | Non-linear pattern learning |

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 10. Model Training
#
# Train all five registered models on the preprocessed data (SMOTE train set when available). Artefacts sync to the Flask app database.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 11. Hyperparameter Tuning
#
# Randomized search (3-fold CV) on a 40k stratified subsample for **XGBoost** and **Random Forest**, then refit the best estimator on the full training set.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 12. Model Evaluation
#
# Compare all trained models plus the tuned XGBoost on hold-out test metrics and diagnostic charts.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 13. Model Interpretation
#
# Global and local SHAP/LIME explanations for the best baseline model from the registry.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 14. Model Deployment
#
# Verify artefacts, run a prediction smoke test, and persist pipeline state for monitoring. Models are available in the Flask app at `/models/`, `/predictions/`, `/explainability/`.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 15. Monitoring & Maintenance
#
# Track prediction volume, risk distribution, and model performance over time via the analytics dashboard and prediction history.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %% [markdown]
# ---
# ## 16. Model Retraining
#
#
#     **Retrain when:**
#     - Hold-out F1 drops below monitoring threshold
#     - New UCI data refresh or expanded cohort (re-run acquisition)
#     - Scheduled review (e.g. every 30 days)
#
#     Re-execute acquisition → preprocessing → training cells, or run `python scripts/train_all_models.py --email YOUR_EMAIL`.

# %%
pass  # skipped; artefacts restored by resume_from_interpretation.py

# %%
import json
print(json.dumps({"dataset_id": 6, "processed_id": 8, "best_model_id": 35, "tuned_model_path": "/home/schrondinger/Desktop/Gabriel/app/ml/models/notebook_xgboost_tuned.joblib", "row_count": 200000, "metrics": {"accuracy": 0.918425, "precision": 0.9140801320984192, "recall": 0.918425, "f1_score": 0.9018181638203768, "roc_auc": 0.8594223591750862, "training_time_seconds": 0.0, "prediction_time_seconds": 0.09207342998706736, "test_samples": 40000}, "trained_at": "2026-08-08 23:38:50", "figures": ["/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_missing_values.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_correlation_heatmap.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_class_distribution.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_feature_distribution.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_histogram.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_boxplot.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_scatter_plot.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_target_rate_by_category.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_categorical_overview.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_numeric_summary.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_roc_comparison.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_pr_comparison.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_roc_auc.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_accuracy.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_precision.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_recall.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_f1_score.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_training_time.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/comparison_prediction_time.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_confusion_matrix.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_normalized_confusion_matrix.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_prediction_distribution.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_feature_importance.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_roc_curve.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_precision_recall_curve.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/tuned_calibration.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/explain_summary.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/explain_feature_importance.html", "/home/schrondinger/Desktop/Gabriel/notebooks/figures/explain_dependence.html"]}, indent=2))
print('figures_dir', r'/home/schrondinger/Desktop/Gabriel/notebooks/figures')
# Out:
# {
#   "dataset_id": 6,
#   "processed_id": 8,
#   "best_model_id": 35,
#   "tuned_model_path": "/home/schrondinger/Desktop/Gabriel/app/ml/models/notebook_xgboost_tuned.joblib",
#   "row_count": 200000,
#   "metrics": {
#     "accuracy": 0.918425,
#     "precision": 0.9140801320984192,
#     "recall": 0.918425,
#     "f1_score": 0.9018181638203768,
#     "roc_auc": 0.8594223591750862,
#     "training_time_seconds": 0.0,
#     "prediction_time_seconds": 0.09207342998706736,
#     "test_samples": 40000
#   },
#   "trained_at": "2026-08-08 23:38:50",
#   "figures": [
#     "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_missing_values.html",
#     "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_correlation_heatmap.html",
#     "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_class_distribution.html",
#     "/home/schrondinger/Desktop/Gabriel/notebooks/figures/eda_feature_distribution.html",
# ...
